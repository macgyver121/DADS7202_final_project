# %% [markdown]
# <a href="https://colab.research.google.com/github/macgyver121/DADS7202_final_project/blob/main/tesseract_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 20 not upgraded.
# Need to get 4,795 kB of archives.
# After this operation, 15.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-eng all 4.00~git24-0e00fe6-1.2 [1,588 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-osd all 4.00~git24-0e00fe6-1.2 [2,989 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr amd64 4.00~git2288-10f4998a-2 [218 kB]
# ...

# %%
import os
os.kill(os.getpid(), 9)

# %%
import cv2
import pytesseract

# %%
import pytesseract
import shutil
import os
import random
from PIL import Image

# %%
print(Image.__version__)
# Out:
# 9.3.0

# %%
import sys
print(sys.version)
# Out:
# 3.8.16 (default, Dec  7 2022, 01:12:13)
# [GCC 7.5.0]

# %%
image_path_in_colab='/content/10.png'
extractedInformation = pytesseract.image_to_string(Image.open(image_path_in_colab))
print(extractedInformation)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-fd2a9aa40cc7> in <module>
#       1 image_path_in_colab='/content/10.png'
# ----> 2 extractedInformation = pytesseract.image_to_string(Image.open(image_path_in_colab))
#       3 print(extractedInformation)
#
# /usr/local/lib/python3.8/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3129
#    3130     if filename:
# -> 3131         fp = builtins.open(filename, "rb")
#    3132         exclusive_fp = True
#    3133
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/10.png'

# %%
type(extractedInformation)
# Out:
# str

# %%
image_path_in_colab='/content/line_14.png'
extractedInformation = pytesseract.image_to_string(Image.open(image_path_in_colab))
print(extractedInformation)
# Out:
# 15
#
# 10
#
# Outokumpu share price, €
#
#
#
# 2006
#
# 2007
#
# 2008
#
# 2009
#
# 2010

# %% [markdown]
# ---------------

# %%
from pytesseract import Output
src = '/content/1-1.JPG'
img = cv2.imread(src)

# %%
#img = cv2.resize(img, (600,600))

# %%
from IPython.display import Image, display
display(Image('/content/1-1.JPG'))

# %%
# Adding custom options
custom_config = r'--psm 1'
text = pytesseract.image_to_string(img, config=custom_config)
print(text)
# Out:
# The chart shows the average number of hours each day that Chinese, American, Turkish and Brazilian tourists
# spent doing leisure activities while on holiday in Greece in August 2019.
#
#
#
# At the beach Reading books Visiting places
#
#
#
# Chinese tourists 3 8 1
#
#
#
# American tourists
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 4 5 3
# Turkish tourists 5 4 3
# Brazilian tourists 6 4 2

# %%
text_split = text.split('\n')
print(text_split)
# Out:
# ['The chart shows the average number of hours each day that Chinese, American, Turkish and Brazilian tourists', 'spent doing leisure activities while on holiday in Greece in August 2019.', '', ' ', '', 'At the beach Reading books Visiting places', '', ' ', '', 'Chinese tourists 3 8 1', '', ' ', '', 'American tourists', '', ' ', '', ' ', '', ' ', '', ' ', '', ' ', '', ' ', '', ' ', '', '4 5 3', 'Turkish tourists 5 4 3', 'Brazilian tourists 6 4 2', '', ' ', '\x0c']

# %%
while '' in text_split:
    text_split.remove('')

# %%
while ' ' in text_split:
    text_split.remove(' ')

# %%
print(text_split)
# Out:
# ['The chart shows the average number of hours each day that Chinese, American, Turkish and Brazilian tourists', 'spent doing leisure activities while on holiday in Greece in August 2019.', 'At the beach Reading books Visiting places', 'Chinese tourists 3 8 1', 'American tourists', '4 5 3', 'Turkish tourists 5 4 3', 'Brazilian tourists 6 4 2', '\x0c']

# %% [markdown]
# -------------------------

# %%
from pytesseract import Output
src = '/content/line1.png'
img = cv2.imread(src)

# %%
from IPython.display import Image, display
display(Image('/content/line1.png'))

# %%
# Adding custom options
custom_config = r'--psm 11'
text = pytesseract.image_to_string(img, config=custom_config)
print(text)
# Out:
# chanel one news viewing figures
#
# millions of viewers per day
#
# 1pm
#
# 6pm
#
# 9.30pm
#
# 11pm
#
# Jan
#
# 13
#
# 48
#
# 3.2
#
# Feb
#
# 1.25
#
# 45
#
# 3.4
#
# Mar
#
# 13
#
# 3.8
#
# 3.5
#
# Apr
#
# 1.26
#
# 45
#
# 3.6
#
# 13
#
# 3.8
#
# 3.8
#
# 0.2
#
# May
#
# Jun
#
# 1.25
#
# 4.2
#
# 2.8
#
# 1.8
#
# Jul
#
# 13
#
# 3.6
#
# 2.2
#
# 3.2
#
# Aug
#
# 13
#
# 3.4
#
# 1.2
#
# 4.1
#
# 13
#
# 3.2
#
# 3.2
#
# Sep
#
# Oct
#
# 1.23
#
# 4
#
# 2.4
#
# 1.8
#
# Nov
#
# 13
#
# 3.8
#
# 2.6
#
# 1.6
#
# Dec
#
# 1.35
#
# 3.2
#
# 14

# %%
text_split = text.split('\n')
print(text_split)
# Out:
# ['The chart below shows the proportions of the world’s oil resources held in different areas, together with the proportions consumed annually in the same areas', '', 'Middle', '', 'Canada', '', '‘America', '', 'Africa', '', 'Asia', '', 'USA’', '', 'Australia', '', 'Other', '', 'Eastern Europe', '', 'Western Europe', '', 'East', '', 'Total world oil resources', '', '56.52%', '', '14.84%', '', '8.12%', '', '6.58%', '', '6.38%', '', '2.89%', '', '1.85%', '', '1.47%', '', '0.30%', '', '1.05%', '', '“Total world annual oll consumption', '', '6.15%', '', '2.48%', '', '6.70%', '', '6.56%', '', '3.35%', '', '26.21%', '', '25.48%', '', '19.24%', '', '1.31%', '', '2.52%', '\x0c']

# %%
while '' in text_split:
    text_split.remove('')
while ' ' in text_split:
    text_split.remove(' ')
print(text_split)
# Out:
# ['The chart below shows the proportions of the world’s oil resources held in different areas, together with the proportions consumed annually in the same areas', 'Middle', 'Canada', '‘America', 'Africa', 'Asia', 'USA’', 'Australia', 'Other', 'Eastern Europe', 'Western Europe', 'East', 'Total world oil resources', '56.52%', '14.84%', '8.12%', '6.58%', '6.38%', '2.89%', '1.85%', '1.47%', '0.30%', '1.05%', '“Total world annual oll consumption', '6.15%', '2.48%', '6.70%', '6.56%', '3.35%', '26.21%', '25.48%', '19.24%', '1.31%', '2.52%', '\x0c']

# %% [markdown]
# -------

# %%
from pytesseract import Output
src = '/content/19_150.png'
img = cv2.imread(src)

# %%
from IPython.display import Image, display
display(Image('/content/19_150.png'))

# %%
# Adding custom options
custom_config = r'--psm 12'
text = pytesseract.image_to_string(img, config=custom_config)
print(text)
# Out:
# Pittsburgh Steelers
#
# Dallas Cowboys
#
# Denver Broncos
#
# San Francisco 49ers
#
# Washington Redskins
#
# Green Bay Packers
#
# Miami Dolphins
#
# New York Giants
#
# Oakland Raiders
#
# Buffalo Bills
#
# Minnesota Vikings
#
# Indianapolis Colts
#
# Los Angeles Rams
#
# Philadelphia Eagles
#
# Kansas City Chiefs
#
# Seattle Seahawks
#
# Carolina Panthers
#
# Atlanta Falcons
#
# Baltimore Ravens
#
# Cincinnati Bengals
#
# Chicago Bears
#
# New Orleans Saints
#
# Arizona Cardinals
#
# Tennessee Titans
#
# Tampa Bay Buccaneers
#
# Papa} a] ef rp ofp rt rst wf wl wf al ala] al cl of clo] oa] | 0 co] 09}

# %% [markdown]
# ----------

# %%
from pytesseract import Output
src = '/content/Capture1.JPG'
img = cv2.imread(src)

# %%
from IPython.display import Image, display
display(Image('/content/Capture1.JPG'))

# %%
# Adding custom options
custom_config = r'--psm 12'
text = pytesseract.image_to_string(img, config=custom_config)
print(text)
# Out:
# The table gives information about department and online stores in Australia in 2011.
#
# Summarise the information by selecting and reporting the main features, and make comparisons where
#
# relevant.
#
# Department Stores
#
# Online Stores
#
# Number of Businesses
#
# 67
#
# 368
#
# 807
#
# 863
#
# Profit (AUD)
#
# Sales Revenue (AUD)
#
# 12,700
#
# 13,400
#
# Growth
#
# 4%
#
# 6%

# %%
text_split = text.split('\n')
print(text_split)
# Out:
# ['The table gives information about department and online stores in Australia in 2011.', '', 'Summarise the information by selecting and reporting the main features, and make comparisons where', '', 'relevant.', '', 'Department Stores', '', 'Online Stores', '', 'Number of Businesses', '', '67', '', '368', '', '807', '', '863', '', 'Profit (AUD)', '', 'Sales Revenue (AUD)', '', '12,700', '', '13,400', '', 'Growth', '', '4%', '', '6%', '\x0c']

# %%
while '' in text_split:
    text_split.remove('')

# %%
print(text_split)
# Out:
# ['The table gives information about department and online stores in Australia in 2011.', 'Summarise the information by selecting and reporting the main features, and make comparisons where', 'relevant.', 'Department Stores', 'Online Stores', 'Number of Businesses', '67', '368', '807', '863', 'Profit (AUD)', 'Sales Revenue (AUD)', '12,700', '13,400', 'Growth', '4%', '6%', '\x0c']

# %% [markdown]
# -----------

# %%
from pytesseract import Output

src = '/content/0.png'
img = cv2.imread(src)
img2 = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)

#d = pytesseract.image_to_data(img, output_type=Output.DICT)
#print(d.keys())

# %%
custom_config = r'--psm 6'
text = pytesseract.image_to_string(img, config=custom_config)
text2 = pytesseract.image_to_string(img2, config=custom_config)

# %%
text_split = text.split('\n')
text2_split = text2.split('\n')

# %%
from IPython.display import Image

# %%
print('Chart 0')
print('Title : '+text_split[0])
print('X-axis : '+text_split[-2])
print('Y-axis : '+text2_split[0])
Image(img)
# Out:
# Chart 0
# Title : Facebook : number of monthly active users worldwide 2008 - 2019\n
# X-axis : Quarter
# Y-axis : Number of users in millions

# %%
from IPython.display import Image, display
display(Image('/content/0.png'))

# %% [markdown]
# ------------

# %%
from pytesseract import Output
for i in range(0,11) :
    src = f'/content/{i}.png'
    img = cv2.imread(src)
    img2 = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)

    custom_config = r'--psm 6'
    text = pytesseract.image_to_string(img, config=custom_config)
    text2 = pytesseract.image_to_string(img2, config=custom_config)

    text_split = text.split('\n')
    text2_split = text2.split('\n')

    print(f'Chart{i}')
    print('Title : '+text_split[0])
    print('X-axis : '+text_split[-2])
    print('Y-axis : '+text2_split[0])
# Out:
# Chart0
# Title : Facebook : number of monthly active users worldwide 2008 - 2019\n
# X-axis : Quarter
# Y-axis : Number of users in millions
# Chart1
# Title : National Basketball Association all-time scoring leaders 1946 to 2020
# X-axis : NBA player
# Y-axis : Number of points scored
# Chart2
# Title : Instagram accounts with the most followers worldwide 2020
# X-axis : Platform
# Y-axis : Number of followers in millions
# Chart3
# Title : National Football League : Super Bowl wins by team 2020
# X-axis : Team
# Y-axis : Super Bowl wins
# Chart4
# Title : Top companies in the world by market value 2019
# X-axis : Ranking of the companies rank 1 to 100
# Y-axis : Market value in billion U.S. dollars
# Chart5
# Title : Most played PC games 2015
# X-axis : Video Game
# Y-axis : Share of playing time
# Chart6
# Title : Homicide - number of murders by U.S. state in 2018
# X-axis : State
# Y-axis : Number of murder victims
# Chart7
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import io

from PIL import Image  # https://pillow.readthedocs.io/en/4.3.x/
import requests  # http://docs.python-requests.org/en/master/

# example image url: https://m.media-amazon.com/images/S/aplus-media/vc/6a9569ab-cb8e-46d9-8aea-a7022e58c74a.jpg

def download_image(url, image_file_path):
    r = requests.get(url, timeout=4.0)
    if r.status_code != requests.codes.ok:
        assert False, 'Status code error: {}.'.format(r.status_code)
    with Image.open(io.BytesIO(r.content)) as im:
        im.save(image_file_path)
    print('Image downloaded from url: {} and saved to: {}.'.format(url, image_file_path))

# %%
url = f'https://raw.githubusercontent.com/JasonObeid/Chart2TextImages/main/images/matplot/0.png'
image_file_path = '/content/sample_data'

# %%
for i in range(0,11):
    download_image(url, image_file_path)
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# <ipython-input-60-ea7801d96dfc> in <module>
#       1 for i in range(0,11):
# ----> 2     download_image(url, image_file_path)
#
# <ipython-input-58-83022f9e950c> in download_image(url, image_file_path)
#      10     if r.status_code != requests.codes.ok:
#      11         assert False, 'Status code error: {}.'.format(r.status_code)
# ---> 12     with Image.open(io.BytesIO(r.content)) as im:
#      13         im.save(image_file_path)
#      14     print('Image downloaded from url: {} and saved to: {}.'.format(url, image_file_path))
#
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3185         warnings.warn(message)
#    3186     raise UnidentifiedImageError(
# -> 3187         "cannot identify image file %r" % (filename if filename else fp)
#    3188     )
#    3189
#
# ...

# %%
download_image(url, image_file_path)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py in save(self, fp, format, **params)
#    2330             try:
# -> 2331                 format = EXTENSION[ext]
#    2332             except KeyError as e:
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-510cf831841a> in <module>
# ----> 1 download_image(url, image_file_path)
#
# <ipython-input-67-83022f9e950c> in download_image(url, image_file_path)
#      11         assert False, 'Status code error: {}.'.format(r.status_code)
#      12     with Image.open(io.BytesIO(r.content)) as im:
# ---> 13         im.save(image_file_path)
#      14     print('Image downloaded from url: {} and saved to: {}.'.format(url, image_file_path))
#
# ...

# %%
# Import the necessary libraries
import cv2
import pytesseract

# Read the image and convert it to grayscale
image = cv2.imread('10.png')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply thresholding to convert the image to black and white
threshold = cv2.threshold(gray, 225, 255, cv2.THRESH_BINARY_INV)[1]

# Find the contours of the chart
contours, _ = cv2.findContours(threshold, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Find the bounding boxes of the contours
bounding_boxes = [cv2.boundingRect(c) for c in contours]

# Iterate through the bounding boxes and extract the text from each chart
for (x, y, w, h) in bounding_boxes:
    # Crop the chart to get just the text we want
    chart = threshold[y:y+h, x:x+w]

    # Use pytesseract to extract the text from the chart
    text = pytesseract.image_to_string(chart)

    # Print the extracted text
    print(text)
# Out:
# i
#
#
#
#
#
#
# uo eta
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# —
